# %% [markdown]
# # Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data

# %%
customers = pd.read_csv('Customers.csv',encoding='latin-1')
exchange_rate = pd.read_csv('Exchange_Rates.csv')
products = pd.read_csv('Products.csv')
sales = pd.read_csv('Sales.csv')
stores = pd.read_csv('Stores.csv')

# %% [markdown]
# # 1. Customers

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent    Birthday
# 0        South Australia     5523      Australia      Australia    7/3/1939
# 1      Western Australia     6522      Australia      Australia   9/27/1979
# 2               Victoria     3380      Australia      Australia   5/26/1947
# 3        South Australia     5223      Australia      Australia   9/17/1957
# 4               Victoria     3698      Australia      Australia  11/19/1965
# ...                  ...      ...            ...            ...         ...
# 15261              Texas    77017  United States  North America   3/25/1936
# 15262           Virginia    22101  United States  North America   2/16/1992
# 15263     North Carolina    28405  United States  North America   11/9/1937
# 15264         California    92501  United States  North America  10/12/1937
# 15265           Michigan    48302  United States  North America   8/18/1965
#
# [15266 rows x 10 columns]

# %%
customers.describe()
# Out:
#         CustomerKey
# count  1.526600e+04
# mean   1.060508e+06
# std    6.127097e+05
# min    3.010000e+02
# 25%    5.140335e+05
# 50%    1.079244e+06
# 75%    1.593980e+06
# max    2.099937e+06

# %%
customers.duplicated().sum()
# Out:
# 0

# %%
customers.isnull().sum()
# Out:
# CustomerKey     0
# Gender          0
# Name            0
# City            0
# State Code     10
# State           0
# Zip Code        0
# Country         0
# Continent       0
# Birthday        0
# dtype: int64

# %% [markdown]
# ## State code is missing for 10 Customers from Napoli. It's ok to keep/drop, we can fill State Code for "Napoli" with "NA"

# %%
customers['State Code'].isnull().sum()
# Out:
# 10

# %%
customers[customers['State Code'].isnull()]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica        NaN
# 5316       732289    Male        Indro Piccio          Varcaturo        NaN
# 5372       742042    Male     Amaranto Loggia          Casaferro        NaN
# 5377       742886  Female       Edmonda Capon           Terzigno        NaN
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco        NaN
# 5485       759705    Male    Callisto Lo Duca            Casilli        NaN
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi        NaN
# 5531       766410    Male   Adelmio Beneventi             Licola        NaN
# 5631       781667  Female          Ilda Manna             Napoli        NaN
# 5695       789177    Male   Calogero Folliero      Mariglianella        NaN
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# 5316  Napoli    80014   Italy    Europe   2/24/1949
# 5372  Napoli    80034   Italy    Europe   3/14/1936
# 5377  Napoli    80040   Italy    Europe    8/6/1963
# 5378  Napoli    80038   Italy    Europe    1/5/1961
# 5485  Napoli    80047   Italy    Europe   8/28/1976
# 5525  Napoli    80045   Italy    Europe  11/13/1947
# 5531  Napoli    80078   Italy    Europe   1/13/1940
# 5631  Napoli    80134   Italy    Europe    5/8/1977
# 5695  Napoli    80030   Italy    Europe    3/3/2000

# %%
customers['State Code'].fillna("NA", inplace=True)

customers[customers['State'] == "Napoli"]
# Out:
#       CustomerKey  Gender                Name               City State Code  \
# 5304       729681  Female    Rossana Padovesi            Polvica         NA
# 5316       732289    Male        Indro Piccio          Varcaturo         NA
# 5372       742042    Male     Amaranto Loggia          Casaferro         NA
# 5377       742886  Female       Edmonda Capon           Terzigno         NA
# 5378       743343  Female        Ambra Sagese  Pomigliano D'Arco         NA
# 5485       759705    Male    Callisto Lo Duca            Casilli         NA
# 5525       765589    Male  Michelino Lucchesi       Pompei Scavi         NA
# 5531       766410    Male   Adelmio Beneventi             Licola         NA
# 5631       781667  Female          Ilda Manna             Napoli         NA
# 5695       789177    Male   Calogero Folliero      Mariglianella         NA
#
#        State Zip Code Country Continent    Birthday
# 5304  Napoli    80035   Italy    Europe   4/18/1981
# 5316  Napoli    80014   Italy    Europe   2/24/1949
# 5372  Napoli    80034   Italy    Europe   3/14/1936
# 5377  Napoli    80040   Italy    Europe    8/6/1963
# 5378  Napoli    80038   Italy    Europe    1/5/1961
# 5485  Napoli    80047   Italy    Europe   8/28/1976
# 5525  Napoli    80045   Italy    Europe  11/13/1947
# 5531  Napoli    80078   Italy    Europe   1/13/1940
# 5631  Napoli    80134   Italy    Europe    5/8/1977
# 5695  Napoli    80030   Italy    Europe    3/3/2000

# %%
customers.isnull().sum()
# Out:
# CustomerKey    0
# Gender         0
# Name           0
# City           0
# State Code     0
# State          0
# Zip Code       0
# Country        0
# Continent      0
# Birthday       0
# dtype: int64

# %% [markdown]
# # Calculating age of the customers from DOB

# %%
from datetime import datetime

# %%
datetime.today()
# Out:
# datetime.datetime(2024, 8, 27, 16, 46, 26, 592697)

# %%
# Convert 'Birthday' column to datetime
customers['Birthday'] = pd.to_datetime(customers['Birthday'], format='%m/%d/%Y')

# Function to calculate age
def calculate_age(born):
    today = datetime.today()
    age = today.year - born.year - ((today.month, today.day) < (born.month, born.day))
    return age

# Apply the function to the 'Birthday' column
customers['Age'] = customers['Birthday'].apply(calculate_age)

# %%
customers
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
#                    State Zip Code        Country      Continent   Birthday  \
# 0        South Australia     5523      Australia      Australia 1939-07-03
# 1      Western Australia     6522      Australia      Australia 1979-09-27
# 2               Victoria     3380      Australia      Australia 1947-05-26
# 3        South Australia     5223      Australia      Australia 1957-09-17
# 4               Victoria     3698      Australia      Australia 1965-11-19
# ...                  ...      ...            ...            ...        ...
# 15261              Texas    77017  United States  North America 1936-03-25
# 15262           Virginia    22101  United States  North America 1992-02-16
# 15263     North Carolina    28405  United States  North America 1937-11-09
# 15264         California    92501  United States  North America 1937-10-12
# 15265           Michigan    48302  United States  North America 1965-08-18
#
#        Age
# 0       85
# 1       44
# 2       77
# 3       66
# 4       58
# ...    ...
# 15261   88
# 15262   32
# 15263   86
# 15264   86
# 15265   59
#
# [15266 rows x 11 columns]

# %%
customers['Gender'].value_counts()
# Out:
# Gender
# Male      7748
# Female    7518
# Name: count, dtype: int64

# %%
#  Gender Distribution:

plt.figure(figsize=(6, 4))
sns.countplot(data=customers, x='Gender')
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %%
# Age Distribution:

plt.figure(figsize=(8, 6))
sns.histplot(customers['Age'], bins=10, kde=True, color='skyblue')
plt.title('Age Distribution of Customers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
# Customers by State:

plt.figure(figsize=(10, 6))
sns.countplot(data=customers, x='State')
plt.title('Number of Customers by State')
plt.xlabel('Count')
plt.ylabel('State')
plt.show()

# %%
#Customers by Continent:

plt.figure(figsize=(6, 4))
sns.countplot(data=customers, x='Continent')
plt.title('Customers by Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.show()

# %%
# visualize country counts
plt.figure(figsize=(12,5))
sns.countplot(x=customers["Country"],data=customers)
plt.xlabel("Country")
plt.ylabel("counts")
plt.title("counts as per Country")
# Out:
# Text(0.5, 1.0, 'counts as per Country')

# %% [markdown]
# # 2. Exchange Rate

# %%
exchange_rate
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
exchange_rate.isna().sum()
# Out:
# Date        0
# Currency    0
# Exchange    0
# dtype: int64

# %%
exchange_rate.duplicated().sum()
# Out:
# 0

# %%
exchange_rate.describe()
# Out:
#            Exchange
# count  11215.000000
# mean       1.061682
# std        0.245519
# min        0.628500
# 25%        0.857800
# 50%        1.000000
# 75%        1.311900
# max        1.725300

# %%
exchange_rate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11215 entries, 0 to 11214
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      11215 non-null  object
#  1   Currency  11215 non-null  object
#  2   Exchange  11215 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 263.0+ KB

# %%
#plot exchange rate, currency wise over the date
plt.figure(figsize=(10,6))
sns.lineplot(data=exchange_rate,x='Date',y='Exchange',hue='Currency')
# Out:
# <Axes: xlabel='Date', ylabel='Exchange'>

# %%
sns.boxplot(x='Currency', y = 'Exchange', data = exchange_rate)
# Out:
# <Axes: xlabel='Currency', ylabel='Exchange'>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(exchange_rate['Exchange'], bins=10, kde=True, color='skyblue')
plt.title('Distribution of Exchange Rates')
plt.xlabel('Exchange Rate')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# # 3. Products

# %%
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# 0     Silver        $6.62         $12.99              101
# 1       Blue        $6.62         $12.99              101
# 2      White        $7.40         $14.52              101
# 3     Silver       $11.00         $21.57              101
# 4        Red       $11.00         $21.57              101
# ...      ...           ...            ...             ...
# 2512     Red       $43.07        $129.99              505
# 2513   White       $43.07        $129.99              505
# 2514   White        $1.71          $3.35              505
# 2515   Black        $1.71          $3.35              505
# 2516  Silver        $1.71          $3.35              505
#
#                   Subcategory  CategoryKey     Category
# 0                     MP4&MP3            1        Audio
# 1                     MP4&MP3            1        Audio
# 2                     MP4&MP3            1        Audio
# 3                     MP4&MP3            1        Audio
# 4                     MP4&MP3            1        Audio
# ...                       ...          ...          ...
# 2512  Cell phones Accessories            5  Cell phones
# 2513  Cell phones Accessories            5  Cell phones
# 2514  Cell phones Accessories            5  Cell phones
# 2515  Cell phones Accessories            5  Cell phones
# 2516  Cell phones Accessories            5  Cell phones
#
# [2517 rows x 10 columns]

# %%
# Check for duplicate records
products.duplicated().sum()
# Out:
# 0

# %%
# Checking for missing values
products.isnull().sum()
# Out:
# ProductKey        0
# Product Name      0
# Brand             0
# Color             0
# Unit Cost USD     0
# Unit Price USD    0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# dtype: int64

# %% [markdown]
# # Units cost & price is prefixed with $ symbol and keep the cost & price as float for easy calculations

# %%
# Remove $ & spaces from Products Unit Cost  & Price, covert as float and create a new col in dataframe
products['Unit Cost'] = products['Unit Cost USD'].str.replace('[$, ]', '', regex=True).astype(float)
products['Unit Price'] = products['Unit Price USD'].str.replace('[$, ]', '', regex=True).astype(float)

# %%
products
# Out:
#       ProductKey                                   Product Name    Brand  \
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color Unit Cost USD Unit Price USD  SubcategoryKey  \
# 0     Silver        $6.62         $12.99              101
# 1       Blue        $6.62         $12.99              101
# 2      White        $7.40         $14.52              101
# 3     Silver       $11.00         $21.57              101
# 4        Red       $11.00         $21.57              101
# ...      ...           ...            ...             ...
# 2512     Red       $43.07        $129.99              505
# 2513   White       $43.07        $129.99              505
# 2514   White        $1.71          $3.35              505
# 2515   Black        $1.71          $3.35              505
# 2516  Silver        $1.71          $3.35              505
#
#                   Subcategory  CategoryKey     Category  Unit Cost  Unit Price
# 0                     MP4&MP3            1        Audio       6.62       12.99
# 1                     MP4&MP3            1        Audio       6.62       12.99
# 2                     MP4&MP3            1        Audio       7.40       14.52
# 3                     MP4&MP3            1        Audio      11.00       21.57
# 4                     MP4&MP3            1        Audio      11.00       21.57
# ...                       ...          ...          ...        ...         ...
# 2512  Cell phones Accessories            5  Cell phones      43.07      129.99
# 2513  Cell phones Accessories            5  Cell phones      43.07      129.99
# 2514  Cell phones Accessories            5  Cell phones       1.71        3.35
# 2515  Cell phones Accessories            5  Cell phones       1.71        3.35
# 2516  Cell phones Accessories            5  Cell phones       1.71        3.35
#
# [2517 rows x 12 columns]

# %%
products.describe()
# Out:
#         ProductKey  SubcategoryKey  CategoryKey    Unit Cost   Unit Price
# count  2517.000000     2517.000000  2517.000000  2517.000000  2517.000000
# mean   1259.000000      491.810091     4.878824   147.655562   356.830131
# std     726.739637      229.887134     2.299170   184.373683   494.054962
# min       1.000000      101.000000     1.000000     0.480000     0.950000
# 25%     630.000000      305.000000     3.000000    32.250000    69.000000
# 50%    1259.000000      406.000000     4.000000    86.670000   199.990000
# 75%    1888.000000      801.000000     8.000000   183.950000   410.000000
# max    2517.000000      808.000000     8.000000  1060.220000  3199.990000

# %%
plt.figure(figsize=(20, 6))
color_counts = products['Color'].value_counts()
plt.pie(color_counts, labels=color_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Product Color Distribution')
plt.show()

# %%
# Visualization of brand and category
plt.figure(figsize=(50,8))
plt.subplot(1,2,1)
sns.countplot(x=products["Brand"],data=products)
plt.xlabel("Brand")
plt.ylabel("counts")
plt.title("counts as per Brand")
plt.show()

# %%
# Visualization for Category Distribution

plt.figure(figsize=(40,8))
plt.subplot(2,2,2)
sns.countplot(x=products["Category"],data=products)
plt.xlabel("Category")
plt.ylabel("counts")
plt.title("counts as per Category")
plt.show()

# %% [markdown]
# # 4. sales

# %%
sales
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# 1             0        1048         2           USD
# 2             0        2007         1           USD
# 3             0        1106         7           CAD
# 4             0         373         1           CAD
# ...         ...         ...       ...           ...
# 62879        43         632         3           USD
# 62880         0          98         4           EUR
# 62881         0        1613         2           CAD
# 62882         0        1717         2           CAD
# 62883         0         464         7           CAD
#
# [62884 rows x 9 columns]

# %%
sales.isnull().sum()
# Out:
# Order Number         0
# Line Item            0
# Order Date           0
# Delivery Date    49719
# CustomerKey          0
# StoreKey             0
# ProductKey           0
# Quantity             0
# Currency Code        0
# dtype: int64

# %%
sales.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Delivery date for many of the sales records is missing.SO we can drop it

# %%
sales.drop(columns="Delivery Date",inplace= True)

# %%
sales.describe()
# Out:
#        Order Number     Line Item   CustomerKey      StoreKey    ProductKey  \
# count  6.288400e+04  62884.000000  6.288400e+04  62884.000000  62884.000000
# mean   1.430905e+06      2.164207  1.180797e+06     31.802144   1125.859344
# std    4.532963e+05      1.365170  5.859634e+05     22.978188    709.244010
# min    3.660000e+05      1.000000  3.010000e+02      0.000000      1.000000
# 25%    1.121017e+06      1.000000  6.808580e+05      8.000000    437.000000
# 50%    1.498016e+06      2.000000  1.261200e+06     37.000000   1358.000000
# 75%    1.788010e+06      3.000000  1.686496e+06     53.000000   1650.000000
# max    2.243032e+06      7.000000  2.099937e+06     66.000000   2517.000000
#
#            Quantity
# count  62884.000000
# mean       3.144790
# std        2.256371
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        4.000000
# max       10.000000

# %%
sales.isnull().sum()
# Out:
# Order Number     0
# Line Item        0
# Order Date       0
# CustomerKey      0
# StoreKey         0
# ProductKey       0
# Quantity         0
# Currency Code    0
# dtype: int64

# %%
#count 0 in StoreKey
(sales['StoreKey'] == 0).sum()
# Out:
# 13165

# %% [markdown]
# ## StoreKey is 0 for many rows.. There is a Store in Stores with 0. Make sure 0 is a valid store

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
stores[stores['StoreKey']==0]
# Out:
#     StoreKey Country   State  Square Meters Open Date
# 66         0  Online  Online            NaN  1/1/2010

# %%
sales[sales['StoreKey'] == 0]
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 1            366001          1   1/1/2016      1269051         0        1048
# 2            366001          2   1/1/2016      1269051         0        2007
# 3            366002          1   1/1/2016       266019         0        1106
# 4            366002          2   1/1/2016       266019         0         373
# 5            366002          3   1/1/2016       266019         0        1080
# ...             ...        ...        ...          ...       ...         ...
# 62878       2243029          6  2/20/2021       887764         0        1456
# 62880       2243031          1  2/20/2021       511229         0          98
# 62881       2243032          1  2/20/2021       331277         0        1613
# 62882       2243032          2  2/20/2021       331277         0        1717
# 62883       2243032          3  2/20/2021       331277         0         464
#
#        Quantity Currency Code
# 1             2           USD
# 2             1           USD
# 3             7           CAD
# 4             1           CAD
# 5             4           CAD
# ...         ...           ...
# 62878         2           EUR
# 62880         4           EUR
# 62881         2           CAD
# 62882         2           CAD
# 62883         7           CAD
#
# [13165 rows x 8 columns]

# %% [markdown]
# # StoreKey 0 is for Online purchases, we should keep it

# %% [markdown]
# # 5. Stores

# %%
stores
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# 4   12/9/2015
# ..        ...
# 62   3/6/2008
# 63   1/1/2010
# 64   1/1/2012
# 65   1/1/2014
# 66   1/1/2010
#
# [67 rows x 5 columns]

# %%
stores.isnull().sum()
# Out:
# StoreKey         0
# Country          0
# State            0
# Square Meters    1
# Open Date        0
# dtype: int64

# %%
# Visualization for Number of Stores per Country
plt.figure(figsize=(8, 6))
sns.countplot(x='Country', data=stores)
plt.title('Number of Stores per Country')
plt.xlabel('Country')
plt.ylabel('Number of Stores')

# Rotate the x-axis labels
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
stores[stores['Square Meters'].isnull()]

# Hence it is a Online Store Square Meters is "0". So no need any changes

stores.describe()

# Insert cleaned data into DB without merging as a backup

from sqlalchemy import create_engine

database_url = 'mysql+pymysql://root:abcd123@127.0.0.1/DataSpark'
engine = create_engine(database_url)

customers.to_sql(name= "customers",con= engine,if_exists="replace",index= False)
exchange_rate.to_sql(name="exchange_rate",con= engine, if_exists="replace",index= False)
products.to_sql(name="products",con= engine,if_exists="replace",index= False)
sales.to_sql(name="sales",con= engine,if_exists="replace",index=False)
stores.to_sql(name="stores",con= engine,if_exists="replace",index=False)
# Out:
# 67

# %% [markdown]
# # Converting the all dates to date type

# %%
#Birthday in customers to date format
customers['Birthday'] = pd.to_datetime(customers['Birthday'])

#convert Date in exchange to date format
exchange_rate['Date'] = pd.to_datetime(exchange_rate['Date'])

#Order date in Sales to date format
sales['Order Date'] = pd.to_datetime(sales['Order Date'])

#convert Open Date in stores to Date format
stores['Open Date'] = pd.to_datetime(stores['Open Date'])

# %% [markdown]
# # Droping Unwanted columns

# %%
#Drop Unit Cost USD, Unit Price USD from products
products.drop(columns=['Unit Cost USD','Unit Price USD'],inplace=True)

#Drop Name, State Code from customers
customers.drop(columns=['Name','State Code'],inplace=True)

# %% [markdown]
# # Merging all dataframes to a single dataframe with required columns
#  * customers
#  * exchange_rate
#  * products
#  * sales
#  * stores

# %% [markdown]
# # 1. Merging Sales & Products based on product key

# %%
# Merge the two DataFrames on 'ProductKey'

merged_df = pd.merge(sales, products, on='ProductKey', how='inner')

# %%
merged_df.isnull().sum()
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Product Name      0
# Brand             0
# Color             0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# Unit Cost         0
# Unit Price        0
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
merged_df.shape

print("size of merged_df after merging 'Sales' & 'Products' with 'product key': ", merged_df.shape)
# Out:
# size of merged_df after merging 'Sales' & 'Products' with 'product key':  (62884, 17)

# %% [markdown]
# # 2. Merging customers with CustomerKey

# %%
# Merge the DataFrame on 'CustomerKey'

merged_df = pd.merge(merged_df, customers, on='CustomerKey', how='inner')

# %%
merged_df.isna().sum()
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Product Name      0
# Brand             0
# Color             0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# Unit Cost         0
# Unit Price        0
# Gender            0
# City              0
# State             0
# Zip Code          0
# Country           0
# Continent         0
# Birthday          0
# Age               0
# dtype: int64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order Number    62884 non-null  int64
#  1   Line Item       62884 non-null  int64
#  2   Order Date      62884 non-null  datetime64[ns]
#  3   CustomerKey     62884 non-null  int64
#  4   StoreKey        62884 non-null  int64
#  5   ProductKey      62884 non-null  int64
#  6   Quantity        62884 non-null  int64
#  7   Currency Code   62884 non-null  object
#  8   Product Name    62884 non-null  object
#  9   Brand           62884 non-null  object
#  10  Color           62884 non-null  object
#  11  SubcategoryKey  62884 non-null  int64
#  12  Subcategory     62884 non-null  object
#  13  CategoryKey     62884 non-null  int64
#  14  Category        62884 non-null  object
#  15  Unit Cost       62884 non-null  float64
#  16  Unit Price      62884 non-null  float64
#  17  Gender          62884 non-null  object
#  18  City            62884 non-null  object
#  19  State           62884 non-null  object
#  20  Zip Code        62884 non-null  object
#  21  Country         62884 non-null  object
#  22  Continent       62884 non-null  object
#  23  Birthday        62884 non-null  datetime64[ns]
#  24  Age             62884 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(9), object(12)
# memory usage: 12.0+ MB

# %%
merged_df.shape

print("size of merged_df after merging 'Sales,Products' & 'customers' with 'CustomerKey': ", merged_df.shape)
# Out:
# size of merged_df after merging 'Sales,Products' & 'customers' with 'CustomerKey':  (62884, 25)

# %% [markdown]
# # 3. Merging exchage rates Date & Currency

# %%
# prefix ex_ to exchange_rate
exchange_rate = exchange_rate.add_prefix('ex_')

# Merge the DataFrames on 'Date' & 'Currency'
merged_df = pd.merge(
    merged_df, 
    exchange_rate, 
    left_on=['Order Date', 'Currency Code'], 
    right_on=['ex_Date', 'ex_Currency'], 
    how='left'
)

# %%
merged_df.isna().sum()
# Out:
# Order Number      0
# Line Item         0
# Order Date        0
# CustomerKey       0
# StoreKey          0
# ProductKey        0
# Quantity          0
# Currency Code     0
# Product Name      0
# Brand             0
# Color             0
# SubcategoryKey    0
# Subcategory       0
# CategoryKey       0
# Category          0
# Unit Cost         0
# Unit Price        0
# Gender            0
# City              0
# State             0
# Zip Code          0
# Country           0
# Continent         0
# Birthday          0
# Age               0
# ex_Date           0
# ex_Currency       0
# ex_Exchange       0
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# 0

# %%
print("size of merged_df after merging exchage rates Date & Currency: ", merged_df.shape)
# Out:
# size of merged_df after merging exchage rates Date & Currency:  (62884, 28)

# %% [markdown]
# # 4. Merging stores with StoreKey

# %%
merged_df.columns
# Out:
# Index(['Order Number', 'Line Item', 'Order Date', 'CustomerKey', 'StoreKey',
#        'ProductKey', 'Quantity', 'Currency Code', 'Product Name', 'Brand',
#        'Color', 'SubcategoryKey', 'Subcategory', 'CategoryKey', 'Category',
#        'Unit Cost', 'Unit Price', 'Gender', 'City', 'State', 'Zip Code',
#        'Country', 'Continent', 'Birthday', 'Age', 'ex_Date', 'ex_Currency',
#        'ex_Exchange'],
#       dtype='object')

# %%
stores.columns
# Out:
# Index(['StoreKey', 'Country', 'State', 'Square Meters', 'Open Date'], dtype='object')

# %%
# prefix store_ to stores
stores = stores.add_prefix('store_')

final_df = pd.merge(merged_df, stores, left_on='StoreKey', right_on='store_StoreKey', how='left')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order Number         62884 non-null  int64
#  1   Line Item            62884 non-null  int64
#  2   Order Date           62884 non-null  datetime64[ns]
#  3   CustomerKey          62884 non-null  int64
#  4   StoreKey             62884 non-null  int64
#  5   ProductKey           62884 non-null  int64
#  6   Quantity             62884 non-null  int64
#  7   Currency Code        62884 non-null  object
#  8   Product Name         62884 non-null  object
#  9   Brand                62884 non-null  object
#  10  Color                62884 non-null  object
#  11  SubcategoryKey       62884 non-null  int64
#  12  Subcategory          62884 non-null  object
#  13  CategoryKey          62884 non-null  int64
#  14  Category             62884 non-null  object
#  15  Unit Cost            62884 non-null  float64
#  16  Unit Price           62884 non-null  float64
#  17  Gender               62884 non-null  object
#  18  City                 62884 non-null  object
#  19  State                62884 non-null  object
#  20  Zip Code             62884 non-null  object
#  21  Country              62884 non-null  object
#  22  Continent            62884 non-null  object
#  23  Birthday             62884 non-null  datetime64[ns]
#  24  Age                  62884 non-null  int64
#  25  ex_Date              62884 non-null  datetime64[ns]
#  26  ex_Currency          62884 non-null  object
#  27  ex_Exchange          62884 non-null  float64
#  28  store_StoreKey       62884 non-null  int64
#  29  store_Country        62884 non-null  object
#  30  store_State          62884 non-null  object
#  31  store_Square Meters  49719 non-null  float64
#  32  store_Open Date      62884 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), float64(4), int64(10), object(15)
# memory usage: 15.8+ MB

# %%
final_df.isnull().sum()
# Out:
# Order Number               0
# Line Item                  0
# Order Date                 0
# CustomerKey                0
# StoreKey                   0
# ProductKey                 0
# Quantity                   0
# Currency Code              0
# Product Name               0
# Brand                      0
# Color                      0
# SubcategoryKey             0
# Subcategory                0
# CategoryKey                0
# Category                   0
# Unit Cost                  0
# Unit Price                 0
# Gender                     0
# City                       0
# State                      0
# Zip Code                   0
# Country                    0
# Continent                  0
# Birthday                   0
# Age                        0
# ex_Date                    0
# ex_Currency                0
# ex_Exchange                0
# store_StoreKey             0
# store_Country              0
# store_State                0
# store_Square Meters    13165
# store_Open Date            0
# dtype: int64

# %%
final_df[final_df["store_Square Meters"].isnull()]
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 1           1749017          1 2019-10-15       265598         0        1619
# 5           1749017          3 2019-10-15       265598         0          52
# 6           1749017          2 2019-10-15       265598         0        1764
# 10          1848016          1 2020-01-22      1599716         0        1679
# 12          1848016          2 2020-01-22      1599716         0          23
# ...             ...        ...        ...          ...       ...         ...
# 62844       1446001          1 2018-12-16      1395823         0         720
# 62845       1105002          1 2018-01-09       404256         0         275
# 62855       1837031          1 2020-01-11       215955         0         881
# 62875       1723027          1 2019-09-19      1609370         0        2268
# 62876       1710021          1 2019-09-06      1067403         0         820
#
#        Quantity Currency Code  \
# 1             1           CAD
# 5             1           CAD
# 6             2           CAD
# 10            3           USD
# 12            1           USD
# ...         ...           ...
# 62844         5           USD
# 62845         2           EUR
# 62855         2           CAD
# 62875         2           USD
# 62876         1           GBP
#
#                                             Product Name  \
# 1                           Contoso DVD Player M130 Grey
# 5                    WWI 2GB Pulse Smart pen M100 Silver
# 6           MGS Age of Empires II: The Age of Kings E126
# 10                   MGS Hand Games for kids E300 Silver
# 12           Contoso 8GB MP3 Player new model M820 White
# ...                                                  ...
# 62844  Proseware Slim-Design Fax Machine with Answeri...
# 62845  Contoso Home Theater System 2.1 Channel E1220 ...
# 62855     Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 62875                            WWI Desk Lamp E130 Blue
# 62876  Contoso Home/Office Laptop Power Adapter E300 ...
#
#                       Brand  ...   Birthday  Age    ex_Date  ex_Currency  \
# 1                   Contoso  ... 1971-03-23   53 2019-10-15          CAD
# 5      Wide World Importers  ... 1971-03-23   53 2019-10-15          CAD
# 6             Tailspin Toys  ... 1971-03-23   53 2019-10-15          CAD
# 10            Tailspin Toys  ... 1999-11-28   24 2020-01-22          USD
# 12                  Contoso  ... 1999-11-28   24 2020-01-22          USD
# ...                     ...  ...        ...  ...        ...          ...
# 62844             Proseware  ... 1956-07-18   68 2018-12-16          USD
# 62845               Contoso  ... 1942-09-24   81 2018-01-09          EUR
# 62855               Contoso  ... 1991-07-25   33 2020-01-11          CAD
# 62875  Wide World Importers  ... 1943-08-08   81 2019-09-19          USD
# 62876               Contoso  ... 1981-12-07   42 2019-09-06          GBP
#
#       ex_Exchange  store_StoreKey  store_Country store_State  \
# 1          1.3230               0         Online      Online
# 5          1.3230               0         Online      Online
# 6          1.3230               0         Online      Online
# 10         1.0000               0         Online      Online
# 12         1.0000               0         Online      Online
# ...           ...             ...            ...         ...
# 62844      1.0000               0         Online      Online
# 62845      0.8381               0         Online      Online
# 62855      1.3072               0         Online      Online
# 62875      1.0000               0         Online      Online
# 62876      0.8129               0         Online      Online
#
#       store_Square Meters store_Open Date
# 1                     NaN      2010-01-01
# 5                     NaN      2010-01-01
# 6                     NaN      2010-01-01
# 10                    NaN      2010-01-01
# 12                    NaN      2010-01-01
# ...                   ...             ...
# 62844                 NaN      2010-01-01
# 62845                 NaN      2010-01-01
# 62855                 NaN      2010-01-01
# 62875                 NaN      2010-01-01
# 62876                 NaN      2010-01-01
#
# [13165 rows x 33 columns]

# %% [markdown]
# ## Square Meters is null for all StoreKey == 0
#  * So we can fill those Square Meters null values with "0", Hence it is an Online Store

# %%
final_df['store_Square Meters'].fillna(0, inplace=True)

final_df[final_df['store_Square Meters'] == 0]
# Out:
#        Order Number  Line Item Order Date  CustomerKey  StoreKey  ProductKey  \
# 1           1749017          1 2019-10-15       265598         0        1619
# 5           1749017          3 2019-10-15       265598         0          52
# 6           1749017          2 2019-10-15       265598         0        1764
# 10          1848016          1 2020-01-22      1599716         0        1679
# 12          1848016          2 2020-01-22      1599716         0          23
# ...             ...        ...        ...          ...       ...         ...
# 62844       1446001          1 2018-12-16      1395823         0         720
# 62845       1105002          1 2018-01-09       404256         0         275
# 62855       1837031          1 2020-01-11       215955         0         881
# 62875       1723027          1 2019-09-19      1609370         0        2268
# 62876       1710021          1 2019-09-06      1067403         0         820
#
#        Quantity Currency Code  \
# 1             1           CAD
# 5             1           CAD
# 6             2           CAD
# 10            3           USD
# 12            1           USD
# ...         ...           ...
# 62844         5           USD
# 62845         2           EUR
# 62855         2           CAD
# 62875         2           USD
# 62876         1           GBP
#
#                                             Product Name  \
# 1                           Contoso DVD Player M130 Grey
# 5                    WWI 2GB Pulse Smart pen M100 Silver
# 6           MGS Age of Empires II: The Age of Kings E126
# 10                   MGS Hand Games for kids E300 Silver
# 12           Contoso 8GB MP3 Player new model M820 White
# ...                                                  ...
# 62844  Proseware Slim-Design Fax Machine with Answeri...
# 62845  Contoso Home Theater System 2.1 Channel E1220 ...
# 62855     Contoso Optical Wheel OEM PS/2 Mouse E60 White
# 62875                            WWI Desk Lamp E130 Blue
# 62876  Contoso Home/Office Laptop Power Adapter E300 ...
#
#                       Brand  ...   Birthday  Age    ex_Date  ex_Currency  \
# 1                   Contoso  ... 1971-03-23   53 2019-10-15          CAD
# 5      Wide World Importers  ... 1971-03-23   53 2019-10-15          CAD
# 6             Tailspin Toys  ... 1971-03-23   53 2019-10-15          CAD
# 10            Tailspin Toys  ... 1999-11-28   24 2020-01-22          USD
# 12                  Contoso  ... 1999-11-28   24 2020-01-22          USD
# ...                     ...  ...        ...  ...        ...          ...
# 62844             Proseware  ... 1956-07-18   68 2018-12-16          USD
# 62845               Contoso  ... 1942-09-24   81 2018-01-09          EUR
# 62855               Contoso  ... 1991-07-25   33 2020-01-11          CAD
# 62875  Wide World Importers  ... 1943-08-08   81 2019-09-19          USD
# 62876               Contoso  ... 1981-12-07   42 2019-09-06          GBP
#
#       ex_Exchange  store_StoreKey  store_Country store_State  \
# 1          1.3230               0         Online      Online
# 5          1.3230               0         Online      Online
# 6          1.3230               0         Online      Online
# 10         1.0000               0         Online      Online
# 12         1.0000               0         Online      Online
# ...           ...             ...            ...         ...
# 62844      1.0000               0         Online      Online
# 62845      0.8381               0         Online      Online
# 62855      1.3072               0         Online      Online
# 62875      1.0000               0         Online      Online
# 62876      0.8129               0         Online      Online
#
#       store_Square Meters store_Open Date
# 1                     0.0      2010-01-01
# 5                     0.0      2010-01-01
# 6                     0.0      2010-01-01
# 10                    0.0      2010-01-01
# 12                    0.0      2010-01-01
# ...                   ...             ...
# 62844                 0.0      2010-01-01
# 62845                 0.0      2010-01-01
# 62855                 0.0      2010-01-01
# 62875                 0.0      2010-01-01
# 62876                 0.0      2010-01-01
#
# [13165 rows x 33 columns]

# %%
final_df.duplicated().sum()
# Out:
# 0

# %%
final_df.isna().sum()
# Out:
# Order Number           0
# Line Item              0
# Order Date             0
# CustomerKey            0
# StoreKey               0
# ProductKey             0
# Quantity               0
# Currency Code          0
# Product Name           0
# Brand                  0
# Color                  0
# SubcategoryKey         0
# Subcategory            0
# CategoryKey            0
# Category               0
# Unit Cost              0
# Unit Price             0
# Gender                 0
# City                   0
# State                  0
# Zip Code               0
# Country                0
# Continent              0
# Birthday               0
# Age                    0
# ex_Date                0
# ex_Currency            0
# ex_Exchange            0
# store_StoreKey         0
# store_Country          0
# store_State            0
# store_Square Meters    0
# store_Open Date        0
# dtype: int64

# %% [markdown]
# ## Drop duplicate key columns

# %%
final_df.drop(columns=['ex_Date','ex_Currency','store_StoreKey'],inplace=True)

# %%
final_df.shape
# Out:
# (62884, 30)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order Number         62884 non-null  int64
#  1   Line Item            62884 non-null  int64
#  2   Order Date           62884 non-null  datetime64[ns]
#  3   CustomerKey          62884 non-null  int64
#  4   StoreKey             62884 non-null  int64
#  5   ProductKey           62884 non-null  int64
#  6   Quantity             62884 non-null  int64
#  7   Currency Code        62884 non-null  object
#  8   Product Name         62884 non-null  object
#  9   Brand                62884 non-null  object
#  10  Color                62884 non-null  object
#  11  SubcategoryKey       62884 non-null  int64
#  12  Subcategory          62884 non-null  object
#  13  CategoryKey          62884 non-null  int64
#  14  Category             62884 non-null  object
#  15  Unit Cost            62884 non-null  float64
#  16  Unit Price           62884 non-null  float64
#  17  Gender               62884 non-null  object
#  18  City                 62884 non-null  object
#  19  State                62884 non-null  object
#  20  Zip Code             62884 non-null  object
#  21  Country              62884 non-null  object
#  22  Continent            62884 non-null  object
#  23  Birthday             62884 non-null  datetime64[ns]
#  24  Age                  62884 non-null  int64
#  25  ex_Exchange          62884 non-null  float64
#  26  store_Country        62884 non-null  object
#  27  store_State          62884 non-null  object
#  28  store_Square Meters  62884 non-null  float64
#  29  store_Open Date      62884 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(4), int64(9), object(14)
# memory usage: 14.4+ MB

# %% [markdown]
# ## Making reqired changes in column names (lower case ,renaming ,removeing spaces and replace with "_") for easy handeling in DB.

# %%
final_df.columns = final_df.columns.str.lower().str.replace(' ', '_')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_number         62884 non-null  int64
#  1   line_item            62884 non-null  int64
#  2   order_date           62884 non-null  datetime64[ns]
#  3   customerkey          62884 non-null  int64
#  4   storekey             62884 non-null  int64
#  5   productkey           62884 non-null  int64
#  6   quantity             62884 non-null  int64
#  7   currency_code        62884 non-null  object
#  8   product_name         62884 non-null  object
#  9   brand                62884 non-null  object
#  10  color                62884 non-null  object
#  11  subcategorykey       62884 non-null  int64
#  12  subcategory          62884 non-null  object
#  13  categorykey          62884 non-null  int64
#  14  category             62884 non-null  object
#  15  unit_cost            62884 non-null  float64
#  16  unit_price           62884 non-null  float64
#  17  gender               62884 non-null  object
#  18  city                 62884 non-null  object
#  19  state                62884 non-null  object
#  20  zip_code             62884 non-null  object
#  21  country              62884 non-null  object
#  22  continent            62884 non-null  object
#  23  birthday             62884 non-null  datetime64[ns]
#  24  age                  62884 non-null  int64
#  25  ex_exchange          62884 non-null  float64
#  26  store_country        62884 non-null  object
#  27  store_state          62884 non-null  object
#  28  store_square_meters  62884 non-null  float64
#  29  store_open_date      62884 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(4), int64(9), object(14)
# memory usage: 14.4+ MB

# %%
final_df.rename(columns={"ex_exchange":"exchange_value"},inplace= True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_number         62884 non-null  int64
#  1   line_item            62884 non-null  int64
#  2   order_date           62884 non-null  datetime64[ns]
#  3   customerkey          62884 non-null  int64
#  4   storekey             62884 non-null  int64
#  5   productkey           62884 non-null  int64
#  6   quantity             62884 non-null  int64
#  7   currency_code        62884 non-null  object
#  8   product_name         62884 non-null  object
#  9   brand                62884 non-null  object
#  10  color                62884 non-null  object
#  11  subcategorykey       62884 non-null  int64
#  12  subcategory          62884 non-null  object
#  13  categorykey          62884 non-null  int64
#  14  category             62884 non-null  object
#  15  unit_cost            62884 non-null  float64
#  16  unit_price           62884 non-null  float64
#  17  gender               62884 non-null  object
#  18  city                 62884 non-null  object
#  19  state                62884 non-null  object
#  20  zip_code             62884 non-null  object
#  21  country              62884 non-null  object
#  22  continent            62884 non-null  object
#  23  birthday             62884 non-null  datetime64[ns]
#  24  age                  62884 non-null  int64
#  25  exchange_value       62884 non-null  float64
#  26  store_country        62884 non-null  object
#  27  store_state          62884 non-null  object
#  28  store_square_meters  62884 non-null  float64
#  29  store_open_date      62884 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(4), int64(9), object(14)
# memory usage: 14.4+ MB

# %% [markdown]
# # 5. Calculation Part
#
#   * Calculating cost of the products,
#   * Calculating price of the products,
#   * Profit/Loss Calculated in USD
#   * Calculations after applying exchange rates

# %%
# Calculating line wise item profit/loss
# Calculating product cost in usd
final_df['total_cost_usd'] = final_df['quantity'] * final_df['unit_cost']
# Calculating total_price_usd
final_df['total_price_usd'] = final_df['quantity'] * final_df['unit_price']
# Calculating profit/loss
final_df['profit_loss_usd'] = final_df['total_price_usd'] - final_df['total_cost_usd']
# Calculating total_cost_org by applying exchange rate
final_df['total_cost_org'] = final_df['total_cost_usd'] * final_df['exchange_value']
# Calculating total_price_org by applying exchange rate
final_df['total_price_org'] = final_df['total_price_usd'] * final_df['exchange_value']
# Calculating profit/loss
final_df['profit_loss_org'] = final_df['total_price_org'] - final_df['total_cost_org']

# %%
final_df
# Out:
#        order_number  line_item order_date  customerkey  storekey  productkey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1           1749017          1 2019-10-15       265598         0        1619
# 2            891000          2 2017-06-09       265598         9         174
# 3            891000          1 2017-06-09       265598         9         385
# 4            891000          4 2017-06-09       265598         9          87
# ...             ...        ...        ...          ...       ...         ...
# 62879       1511040          1 2019-02-19       957765        40         757
# 62880       1466016          1 2019-01-05       347907         9        2232
# 62881       1625031          1 2019-06-13       725929        30        2308
# 62882       1632012          1 2019-06-20      1292476        65        2331
# 62883       1825024          1 2019-12-30      1546902        50        2479
#
#        quantity currency_code  \
# 0             1           CAD
# 1             1           CAD
# 2             1           CAD
# 3             2           CAD
# 4             1           CAD
# ...         ...           ...
# 62879         6           GBP
# 62880         2           CAD
# 62881         2           EUR
# 62882         2           USD
# 62883         5           USD
#
#                                             product_name  \
# 0                        Contoso Lens Adapter M450 White
# 1                           Contoso DVD Player M130 Grey
# 2                                   SV 22xDVD M600 Black
# 3                    Adventure Works Laptop8.9 E0890 Red
# 4      NT Wireless Bluetooth Stereo Headphones M402 P...
# ...                                                  ...
# 62879       Contoso Enhanced Capacity Battery M800 Black
# 62880                          WWI Chandelier M815 Black
# 62881                     Proseware Desk Lamp E0130 Blue
# 62882                     Litware Wall Lamp E3015 Silver
# 62883   Litware 17'' Oscillating Pedestal Fan M125 White
#
#                       brand  ...   store_country                 store_state  \
# 0                   Contoso  ...          Canada                     Nunavut
# 1                   Contoso  ...          Online                      Online
# 2          Southridge Video  ...          Canada       Northwest Territories
# 3           Adventure Works  ...          Canada       Northwest Territories
# 4         Northwind Traders  ...          Canada       Northwest Territories
# ...                     ...  ...             ...                         ...
# 62879               Contoso  ...  United Kingdom  Dungannon and South Tyrone
# 62880  Wide World Importers  ...          Canada       Northwest Territories
# 62881             Proseware  ...           Italy                      Pesaro
# 62882               Litware  ...   United States               West Virginia
# 62883               Litware  ...   United States                      Kansas
#
#       store_square_meters  store_open_date total_cost_usd  total_price_usd  \
# 0                  1210.0       2015-04-04          31.27            68.00
# 1                     0.0       2010-01-01          27.59            59.99
# 2                  1500.0       2005-03-04          43.04           129.90
# 3                  1500.0       2005-03-04         332.40           652.00
# 4                  1500.0       2005-03-04          45.98            99.99
# ...                   ...              ...            ...              ...
# 62879              1300.0       2012-06-06          76.98           167.40
# 62880              1500.0       2005-03-04         246.94           537.00
# 62881              2100.0       2008-01-12          81.52           159.90
# 62882              1785.0       2012-01-01         104.00           203.98
# 62883              2000.0       2008-03-06         482.85          1050.00
#
#        profit_loss_usd total_cost_org total_price_org profit_loss_org
# 0                36.73      43.415268       94.411200       50.995932
# 1                32.40      36.501570       79.366770       42.865200
# 2                86.86      58.142736      175.481910      117.339174
# 3               319.60     449.039160      880.786800      431.747640
# 4                54.01      62.114382      135.076491       72.962109
# ...                ...            ...             ...             ...
# 62879            90.42      59.428560      129.232800       69.804240
# 62880           290.06     331.936748      721.835400      389.898652
# 62881            78.38      72.210416      141.639420       69.429004
# 62882            99.98     104.000000      203.980000       99.980000
# 62883           567.15     482.850000     1050.000000      567.150000
#
# [62884 rows x 36 columns]

# %%
final_df[final_df['profit_loss_org'] < 0]
# Out:
# Empty DataFrame
# Columns: [order_number, line_item, order_date, customerkey, storekey, productkey, quantity, currency_code, product_name, brand, color, subcategorykey, subcategory, categorykey, category, unit_cost, unit_price, gender, city, state, zip_code, country, continent, birthday, age, exchange_value, store_country, store_state, store_square_meters, store_open_date, total_cost_usd, total_price_usd, profit_loss_usd, total_cost_org, total_price_org, profit_loss_org]
# Index: []
#
# [0 rows x 36 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_number         62884 non-null  int64
#  1   line_item            62884 non-null  int64
#  2   order_date           62884 non-null  datetime64[ns]
#  3   customerkey          62884 non-null  int64
#  4   storekey             62884 non-null  int64
#  5   productkey           62884 non-null  int64
#  6   quantity             62884 non-null  int64
#  7   currency_code        62884 non-null  object
#  8   product_name         62884 non-null  object
#  9   brand                62884 non-null  object
#  10  color                62884 non-null  object
#  11  subcategorykey       62884 non-null  int64
#  12  subcategory          62884 non-null  object
#  13  categorykey          62884 non-null  int64
#  14  category             62884 non-null  object
#  15  unit_cost            62884 non-null  float64
#  16  unit_price           62884 non-null  float64
#  17  gender               62884 non-null  object
#  18  city                 62884 non-null  object
#  19  state                62884 non-null  object
#  20  zip_code             62884 non-null  object
#  21  country              62884 non-null  object
#  22  continent            62884 non-null  object
#  23  birthday             62884 non-null  datetime64[ns]
#  24  age                  62884 non-null  int64
#  25  exchange_value       62884 non-null  float64
#  26  store_country        62884 non-null  object
#  27  store_state          62884 non-null  object
#  28  store_square_meters  62884 non-null  float64
#  29  store_open_date      62884 non-null  datetime64[ns]
#  30  total_cost_usd       62884 non-null  float64
#  31  total_price_usd      62884 non-null  float64
#  32  profit_loss_usd      62884 non-null  float64
#  33  total_cost_org       62884 non-null  float64
#  34  total_price_org      62884 non-null  float64
#  35  profit_loss_org      62884 non-null  float64
# dtypes: datetime64[ns](3), float64(10), int64(9), object(14)
# memory usage: 17.3+ MB

# %%
final_df.describe()
# Out:
#        order_number     line_item                     order_date  \
# count  6.288400e+04  62884.000000                          62884
# mean   1.430905e+06      2.164207  2018-11-30 21:21:56.939126272
# min    3.660000e+05      1.000000            2016-01-01 00:00:00
# 25%    1.121017e+06      1.000000            2018-01-25 00:00:00
# 50%    1.498016e+06      2.000000            2019-02-06 00:00:00
# 75%    1.788010e+06      3.000000            2019-11-23 00:00:00
# max    2.243032e+06      7.000000            2021-02-20 00:00:00
# std    4.532963e+05      1.365170                            NaN
#
#         customerkey      storekey    productkey      quantity  subcategorykey  \
# count  6.288400e+04  62884.000000  62884.000000  62884.000000    62884.000000
# mean   1.180797e+06     31.802144   1125.859344      3.144790      450.198238
# min    3.010000e+02      0.000000      1.000000      1.000000      101.000000
# 25%    6.808580e+05      8.000000    437.000000      1.000000      303.000000
# 50%    1.261200e+06     37.000000   1358.000000      2.000000      501.000000
# 75%    1.686496e+06     53.000000   1650.000000      4.000000      602.000000
# max    2.099937e+06     66.000000   2517.000000     10.000000      808.000000
# std    5.859634e+05     22.978188    709.244010      2.256371      212.710652
#
#         categorykey     unit_cost  ...           age exchange_value  \
# count  62884.000000  62884.000000  ...  62884.000000   62884.000000
# mean       4.469611    116.253013  ...     55.225988       0.992533
# min        1.000000      0.480000  ...     22.000000       0.672500
# 25%        3.000000     22.050000  ...     38.000000       0.894500
# 50%        5.000000     79.530000  ...     55.000000       1.000000
# 75%        6.000000    138.420000  ...     72.000000       1.000000
# max        8.000000   1060.220000  ...     89.000000       1.665200
# std        2.132682    140.033327  ...     19.403486       0.161601
#
#        store_square_meters                store_open_date  total_cost_usd  \
# count         62884.000000                          62884    62884.000000
# mean           1260.640306  2011-05-30 02:16:19.174352640      367.228408
# min               0.000000            2005-03-04 00:00:00        0.480000
# 25%             840.000000            2010-01-01 00:00:00       52.880000
# 50%            1330.000000            2010-01-01 00:00:00      164.160000
# 75%            2000.000000            2013-06-07 00:00:00      423.080000
# max            2105.000000            2019-03-05 00:00:00    10602.200000
# std             767.739494                            NaN      614.548869
#
#       total_price_usd  profit_loss_usd  total_cost_org  total_price_org  \
# count    62884.000000     62884.000000    62884.000000     62884.000000
# mean       886.640156       519.411748      364.533752       880.183610
# min          0.950000         0.470000        0.367056         0.726465
# 25%        115.000000        61.560000       51.120000       110.509108
# 50%        360.000000       194.440000      159.468342       358.869410
# 75%        969.000000       540.140000      416.050000       959.940000
# max      31999.900000     21397.700000    13224.298860     36630.925528
# std       1648.480286      1052.204029      622.199765      1666.199668
#
#        profit_loss_org
# count     62884.000000
# mean        515.649857
# min           0.359409
# 25%          58.678148
# 50%         193.910000
# 75%         538.168878
# max       24494.375144
# std        1062.389875
#
# [8 rows x 22 columns]

# %%
final_df.isnull().sum()
# Out:
# order_number           0
# line_item              0
# order_date             0
# customerkey            0
# storekey               0
# productkey             0
# quantity               0
# currency_code          0
# product_name           0
# brand                  0
# color                  0
# subcategorykey         0
# subcategory            0
# categorykey            0
# category               0
# unit_cost              0
# unit_price             0
# gender                 0
# city                   0
# state                  0
# zip_code               0
# country                0
# continent              0
# birthday               0
# age                    0
# exchange_value         0
# store_country          0
# store_state            0
# store_square_meters    0
# store_open_date        0
# total_cost_usd         0
# total_price_usd        0
# profit_loss_usd        0
# total_cost_org         0
# total_price_org        0
# profit_loss_org        0
# dtype: int64

# %%
final_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 6. Calculate age group of customers

# %%
# Calculate age group of the customers based on their age
final_df['age_group'] = pd.cut(final_df['age'], bins=[0, 20, 40, 60 ,80, 100], labels=['0-20', '20-40', '40-60', '60-80', '80-100'])
     

#print cust_age and cust_age_group
final_df[['age','age_group']].head()
# Out:
#    age age_group
# 0   53     40-60
# 1   53     40-60
# 2   53     40-60
# 3   53     40-60
# 4   53     40-60

# %%
final_df
# Out:
#        order_number  line_item order_date  customerkey  storekey  productkey  \
# 0            366000          1 2016-01-01       265598        10        1304
# 1           1749017          1 2019-10-15       265598         0        1619
# 2            891000          2 2017-06-09       265598         9         174
# 3            891000          1 2017-06-09       265598         9         385
# 4            891000          4 2017-06-09       265598         9          87
# ...             ...        ...        ...          ...       ...         ...
# 62879       1511040          1 2019-02-19       957765        40         757
# 62880       1466016          1 2019-01-05       347907         9        2232
# 62881       1625031          1 2019-06-13       725929        30        2308
# 62882       1632012          1 2019-06-20      1292476        65        2331
# 62883       1825024          1 2019-12-30      1546902        50        2479
#
#        quantity currency_code  \
# 0             1           CAD
# 1             1           CAD
# 2             1           CAD
# 3             2           CAD
# 4             1           CAD
# ...         ...           ...
# 62879         6           GBP
# 62880         2           CAD
# 62881         2           EUR
# 62882         2           USD
# 62883         5           USD
#
#                                             product_name  \
# 0                        Contoso Lens Adapter M450 White
# 1                           Contoso DVD Player M130 Grey
# 2                                   SV 22xDVD M600 Black
# 3                    Adventure Works Laptop8.9 E0890 Red
# 4      NT Wireless Bluetooth Stereo Headphones M402 P...
# ...                                                  ...
# 62879       Contoso Enhanced Capacity Battery M800 Black
# 62880                          WWI Chandelier M815 Black
# 62881                     Proseware Desk Lamp E0130 Blue
# 62882                     Litware Wall Lamp E3015 Silver
# 62883   Litware 17'' Oscillating Pedestal Fan M125 White
#
#                       brand  ...                 store_state  \
# 0                   Contoso  ...                     Nunavut
# 1                   Contoso  ...                      Online
# 2          Southridge Video  ...       Northwest Territories
# 3           Adventure Works  ...       Northwest Territories
# 4         Northwind Traders  ...       Northwest Territories
# ...                     ...  ...                         ...
# 62879               Contoso  ...  Dungannon and South Tyrone
# 62880  Wide World Importers  ...       Northwest Territories
# 62881             Proseware  ...                      Pesaro
# 62882               Litware  ...               West Virginia
# 62883               Litware  ...                      Kansas
#
#        store_square_meters store_open_date  total_cost_usd total_price_usd  \
# 0                   1210.0      2015-04-04           31.27           68.00
# 1                      0.0      2010-01-01           27.59           59.99
# 2                   1500.0      2005-03-04           43.04          129.90
# 3                   1500.0      2005-03-04          332.40          652.00
# 4                   1500.0      2005-03-04           45.98           99.99
# ...                    ...             ...             ...             ...
# 62879               1300.0      2012-06-06           76.98          167.40
# 62880               1500.0      2005-03-04          246.94          537.00
# 62881               2100.0      2008-01-12           81.52          159.90
# 62882               1785.0      2012-01-01          104.00          203.98
# 62883               2000.0      2008-03-06          482.85         1050.00
#
#        profit_loss_usd  total_cost_org total_price_org profit_loss_org  \
# 0                36.73       43.415268       94.411200       50.995932
# 1                32.40       36.501570       79.366770       42.865200
# 2                86.86       58.142736      175.481910      117.339174
# 3               319.60      449.039160      880.786800      431.747640
# 4                54.01       62.114382      135.076491       72.962109
# ...                ...             ...             ...             ...
# 62879            90.42       59.428560      129.232800       69.804240
# 62880           290.06      331.936748      721.835400      389.898652
# 62881            78.38       72.210416      141.639420       69.429004
# 62882            99.98      104.000000      203.980000       99.980000
# 62883           567.15      482.850000     1050.000000      567.150000
#
#       age_group
# 0         40-60
# 1         40-60
# 2         40-60
# 3         40-60
# 4         40-60
# ...         ...
# 62879     20-40
# 62880     60-80
# 62881     20-40
# 62882     20-40
# 62883     60-80
#
# [62884 rows x 37 columns]

# %%
# Profit/Loss Distribution
plt.figure(figsize=(10, 6))
plt.hist(final_df['profit_loss_usd'], bins=30)
plt.title('Profit/Loss Distribution in USD')
plt.xlabel('Profit/Loss (USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
# Profit/Loss by Category
profit_loss_by_category = final_df.groupby('category')['profit_loss_usd'].sum().sort_values()
plt.figure(figsize=(10, 6))
profit_loss_by_category.plot(kind='bar')
plt.title('Total Profit/Loss by Category')
plt.xlabel('Category')
plt.ylabel('Total Profit/Loss (USD)')
plt.grid(True)
plt.show()

# %%
# Profit/Loss over Time
final_df.set_index('order_date')
profit_loss_over_time = final_df['profit_loss_usd'].resample('M').sum()
plt.figure(figsize=(10, 6))
profit_loss_over_time.plot(color='green')
plt.title('Profit/Loss Over Time')
plt.xlabel('Date')
plt.ylabel('Profit/Loss (USD)')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 3
#       1 # Profit/Loss over Time
#       2 final_df.set_index('order_date')
# ----> 3 profit_loss_over_time = final_df['profit_loss_usd'].resample('M').sum()
#       4 plt.figure(figsize=(10, 6))
#       5 profit_loss_over_time.plot(color='green')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:9439, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    9436 else:
#    9437     axis = 0
# -> 9439 return get_resampler(
#    9440     cast("Series | DataFrame", self),
#    9441     freq=rule,
#    9442     label=label,
#    9443     closed=closed,
#    9444     axis=axis,
#    9445     kind=kind,
#    9446     convention=convention,
#    9447     key=on,
#    9448     level=level,
#    9449     origin=origin,
#    9450     offset=offset,
#    9451     group_keys=group_keys,
#    9452 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\resample.py:1970, in get_resampler(obj, kind, **kwds)
#    1966 """
#    1967 Create a TimeGrouper and return our resampler.
#    1968 """
#    1969 tg = TimeGrouper(**kwds)
# -> 1970 return tg._get_resampler(obj, kind=kind)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\resample.py:2160, in TimeGrouper._get_resampler(self, obj, kind)
#    2151 elif isinstance(ax, TimedeltaIndex):
#    2152     return TimedeltaIndexResampler(
#    2153         obj,
#    2154         timegrouper=self,
#    (...)
#    2157         gpr_index=ax,
#    2158     )
# -> 2160 raise TypeError(
#    2161     "Only valid with DatetimeIndex, "
#    2162     "TimedeltaIndex or PeriodIndex, "
#    2163     f"but got an instance of '{type(ax).__name__}'"
#    2164 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %% [markdown]
# # 7. Loading the final_df into SQL DB

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62884 entries, 0 to 62883
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   order_number         62884 non-null  int64
#  1   line_item            62884 non-null  int64
#  2   order_date           62884 non-null  datetime64[ns]
#  3   customerkey          62884 non-null  int64
#  4   storekey             62884 non-null  int64
#  5   productkey           62884 non-null  int64
#  6   quantity             62884 non-null  int64
#  7   currency_code        62884 non-null  object
#  8   product_name         62884 non-null  object
#  9   brand                62884 non-null  object
#  10  color                62884 non-null  object
#  11  subcategorykey       62884 non-null  int64
#  12  subcategory          62884 non-null  object
#  13  categorykey          62884 non-null  int64
#  14  category             62884 non-null  object
#  15  unit_cost            62884 non-null  float64
#  16  unit_price           62884 non-null  float64
#  17  gender               62884 non-null  object
#  18  city                 62884 non-null  object
#  19  state                62884 non-null  object
#  20  zip_code             62884 non-null  object
#  21  country              62884 non-null  object
#  22  continent            62884 non-null  object
#  23  birthday             62884 non-null  datetime64[ns]
#  24  age                  62884 non-null  int64
#  25  exchange_value       62884 non-null  float64
#  26  store_country        62884 non-null  object
#  27  store_state          62884 non-null  object
#  28  store_square_meters  62884 non-null  float64
#  29  store_open_date      62884 non-null  datetime64[ns]
#  30  total_cost_usd       62884 non-null  float64
#  31  total_price_usd      62884 non-null  float64
#  32  profit_loss_usd      62884 non-null  float64
#  33  total_cost_org       62884 non-null  float64
#  34  total_price_org      62884 non-null  float64
#  35  profit_loss_org      62884 non-null  float64
#  36  age_group            62884 non-null  category
# dtypes: category(1), datetime64[ns](3), float64(10), int64(9), object(14)
# memory usage: 17.3+ MB

# %%
final_df.to_sql(name= "dataspark_final_df",con= engine,if_exists="replace",index= False)
# Out:
# 62884

# %%
sales.shape
# Out:
# (62884, 8)

# %%
final_df.shape
# Out:
# (62884, 37)

# %%
final_df.hist(figsize=(15,15))
# Out:
# array([[<Axes: title={'center': 'order_number'}>,
#         <Axes: title={'center': 'line_item'}>,
#         <Axes: title={'center': 'order_date'}>,
#         <Axes: title={'center': 'customerkey'}>,
#         <Axes: title={'center': 'storekey'}>],
#        [<Axes: title={'center': 'productkey'}>,
#         <Axes: title={'center': 'quantity'}>,
#         <Axes: title={'center': 'subcategorykey'}>,
#         <Axes: title={'center': 'categorykey'}>,
#         <Axes: title={'center': 'unit_cost'}>],
#        [<Axes: title={'center': 'unit_price'}>,
#         <Axes: title={'center': 'birthday'}>,
#         <Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'exchange_value'}>,
#         <Axes: title={'center': 'store_square_meters'}>],
#        [<Axes: title={'center': 'store_open_date'}>,
#         <Axes: title={'center': 'total_cost_usd'}>,
#         <Axes: title={'center': 'total_price_usd'}>,
#         <Axes: title={'center': 'profit_loss_usd'}>,
#         <Axes: title={'center': 'total_cost_org'}>],
#        [<Axes: title={'center': 'total_price_org'}>,
#         <Axes: title={'center': 'profit_loss_org'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
final_df.describe()
# Out:
#        order_number     line_item                     order_date  \
# count  6.288400e+04  62884.000000                          62884
# mean   1.430905e+06      2.164207  2018-11-30 21:21:56.939126272
# min    3.660000e+05      1.000000            2016-01-01 00:00:00
# 25%    1.121017e+06      1.000000            2018-01-25 00:00:00
# 50%    1.498016e+06      2.000000            2019-02-06 00:00:00
# 75%    1.788010e+06      3.000000            2019-11-23 00:00:00
# max    2.243032e+06      7.000000            2021-02-20 00:00:00
# std    4.532963e+05      1.365170                            NaN
#
#         customerkey      storekey    productkey      quantity  subcategorykey  \
# count  6.288400e+04  62884.000000  62884.000000  62884.000000    62884.000000
# mean   1.180797e+06     31.802144   1125.859344      3.144790      450.198238
# min    3.010000e+02      0.000000      1.000000      1.000000      101.000000
# 25%    6.808580e+05      8.000000    437.000000      1.000000      303.000000
# 50%    1.261200e+06     37.000000   1358.000000      2.000000      501.000000
# 75%    1.686496e+06     53.000000   1650.000000      4.000000      602.000000
# max    2.099937e+06     66.000000   2517.000000     10.000000      808.000000
# std    5.859634e+05     22.978188    709.244010      2.256371      212.710652
#
#         categorykey     unit_cost  ...           age exchange_value  \
# count  62884.000000  62884.000000  ...  62884.000000   62884.000000
# mean       4.469611    116.253013  ...     55.225988       0.992533
# min        1.000000      0.480000  ...     22.000000       0.672500
# 25%        3.000000     22.050000  ...     38.000000       0.894500
# 50%        5.000000     79.530000  ...     55.000000       1.000000
# 75%        6.000000    138.420000  ...     72.000000       1.000000
# max        8.000000   1060.220000  ...     89.000000       1.665200
# std        2.132682    140.033327  ...     19.403486       0.161601
#
#        store_square_meters                store_open_date  total_cost_usd  \
# count         62884.000000                          62884    62884.000000
# mean           1260.640306  2011-05-30 02:16:19.174352640      367.228408
# min               0.000000            2005-03-04 00:00:00        0.480000
# 25%             840.000000            2010-01-01 00:00:00       52.880000
# 50%            1330.000000            2010-01-01 00:00:00      164.160000
# 75%            2000.000000            2013-06-07 00:00:00      423.080000
# max            2105.000000            2019-03-05 00:00:00    10602.200000
# std             767.739494                            NaN      614.548869
#
#       total_price_usd  profit_loss_usd  total_cost_org  total_price_org  \
# count    62884.000000     62884.000000    62884.000000     62884.000000
# mean       886.640156       519.411748      364.533752       880.183610
# min          0.950000         0.470000        0.367056         0.726465
# 25%        115.000000        61.560000       51.120000       110.509108
# 50%        360.000000       194.440000      159.468342       358.869410
# 75%        969.000000       540.140000      416.050000       959.940000
# max      31999.900000     21397.700000    13224.298860     36630.925528
# std       1648.480286      1052.204029      622.199765      1666.199668
#
#        profit_loss_org
# count     62884.000000
# mean        515.649857
# min           0.359409
# 25%          58.678148
# 50%         193.910000
# 75%         538.168878
# max       24494.375144
# std        1062.389875
#
# [8 rows x 22 columns]

# %%
final_df.columns
# Out:
# Index(['order_number', 'line_item', 'order_date', 'customerkey', 'storekey',
#        'productkey', 'quantity', 'currency_code', 'product_name', 'brand',
#        'color', 'subcategorykey', 'subcategory', 'categorykey', 'category',
#        'unit_cost', 'unit_price', 'gender', 'city', 'state', 'zip_code',
#        'country', 'continent', 'birthday', 'age', 'exchange_value',
#        'store_country', 'store_state', 'store_square_meters',
#        'store_open_date', 'total_cost_usd', 'total_price_usd',
#        'profit_loss_usd', 'total_cost_org', 'total_price_org',
#        'profit_loss_org', 'age_group'],
#       dtype='object')

# %%
final_df.to_csv("dataspark.csv",index=False)

# %%
data = pd.read_csv("dataspark.csv")

# %%
data.columns
# Out:
# Index(['order_number', 'line_item', 'order_date', 'customerkey', 'storekey',
#        'productkey', 'quantity', 'currency_code', 'product_name', 'brand',
#        'color', 'subcategorykey', 'subcategory', 'categorykey', 'category',
#        'unit_cost', 'unit_price', 'gender', 'city', 'state', 'zip_code',
#        'country', 'continent', 'birthday', 'age', 'exchange_value',
#        'store_country', 'store_state', 'store_square_meters',
#        'store_open_date', 'total_cost_usd', 'total_price_usd',
#        'profit_loss_usd', 'total_cost_org', 'total_price_org',
#        'profit_loss_org', 'age_group'],
#       dtype='object')

# %%
data
# Out:
#        order_number  line_item  order_date  customerkey  storekey  productkey  \
# 0            366000          1  2016-01-01       265598        10        1304
# 1           1749017          1  2019-10-15       265598         0        1619
# 2            891000          2  2017-06-09       265598         9         174
# 3            891000          1  2017-06-09       265598         9         385
# 4            891000          4  2017-06-09       265598         9          87
# ...             ...        ...         ...          ...       ...         ...
# 62879       1511040          1  2019-02-19       957765        40         757
# 62880       1466016          1  2019-01-05       347907         9        2232
# 62881       1625031          1  2019-06-13       725929        30        2308
# 62882       1632012          1  2019-06-20      1292476        65        2331
# 62883       1825024          1  2019-12-30      1546902        50        2479
#
#        quantity currency_code  \
# 0             1           CAD
# 1             1           CAD
# 2             1           CAD
# 3             2           CAD
# 4             1           CAD
# ...         ...           ...
# 62879         6           GBP
# 62880         2           CAD
# 62881         2           EUR
# 62882         2           USD
# 62883         5           USD
#
#                                             product_name  \
# 0                        Contoso Lens Adapter M450 White
# 1                           Contoso DVD Player M130 Grey
# 2                                   SV 22xDVD M600 Black
# 3                    Adventure Works Laptop8.9 E0890 Red
# 4      NT Wireless Bluetooth Stereo Headphones M402 P...
# ...                                                  ...
# 62879       Contoso Enhanced Capacity Battery M800 Black
# 62880                          WWI Chandelier M815 Black
# 62881                     Proseware Desk Lamp E0130 Blue
# 62882                     Litware Wall Lamp E3015 Silver
# 62883   Litware 17'' Oscillating Pedestal Fan M125 White
#
#                       brand  ...                 store_state  \
# 0                   Contoso  ...                     Nunavut
# 1                   Contoso  ...                      Online
# 2          Southridge Video  ...       Northwest Territories
# 3           Adventure Works  ...       Northwest Territories
# 4         Northwind Traders  ...       Northwest Territories
# ...                     ...  ...                         ...
# 62879               Contoso  ...  Dungannon and South Tyrone
# 62880  Wide World Importers  ...       Northwest Territories
# 62881             Proseware  ...                      Pesaro
# 62882               Litware  ...               West Virginia
# 62883               Litware  ...                      Kansas
#
#        store_square_meters store_open_date  total_cost_usd total_price_usd  \
# 0                   1210.0      2015-04-04           31.27           68.00
# 1                      0.0      2010-01-01           27.59           59.99
# 2                   1500.0      2005-03-04           43.04          129.90
# 3                   1500.0      2005-03-04          332.40          652.00
# 4                   1500.0      2005-03-04           45.98           99.99
# ...                    ...             ...             ...             ...
# 62879               1300.0      2012-06-06           76.98          167.40
# 62880               1500.0      2005-03-04          246.94          537.00
# 62881               2100.0      2008-01-12           81.52          159.90
# 62882               1785.0      2012-01-01          104.00          203.98
# 62883               2000.0      2008-03-06          482.85         1050.00
#
#        profit_loss_usd  total_cost_org total_price_org profit_loss_org  \
# 0                36.73       43.415268       94.411200       50.995932
# 1                32.40       36.501570       79.366770       42.865200
# 2                86.86       58.142736      175.481910      117.339174
# 3               319.60      449.039160      880.786800      431.747640
# 4                54.01       62.114382      135.076491       72.962109
# ...                ...             ...             ...             ...
# 62879            90.42       59.428560      129.232800       69.804240
# 62880           290.06      331.936748      721.835400      389.898652
# 62881            78.38       72.210416      141.639420       69.429004
# 62882            99.98      104.000000      203.980000       99.980000
# 62883           567.15      482.850000     1050.000000      567.150000
#
#       age_group
# 0         40-60
# 1         40-60
# 2         40-60
# 3         40-60
# 4         40-60
# ...         ...
# 62879     20-40
# 62880     60-80
# 62881     20-40
# 62882     20-40
# 62883     60-80
#
# [62884 rows x 37 columns]
